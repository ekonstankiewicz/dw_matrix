# %%
from google.colab import drive

# %%
ROOT='/content/drive'
drive.mount(ROOT)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
HOME=ROOT+'/My Drive/Colab Notebooks'
HOME
# Out:
# '/content/drive/My Drive/Colab Notebooks'

# %%
# !mkdir -p "{HOME}"

# %%
cd {HOME}
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks'

# %%
GITHUB_TOKEN = 'e47597a565b7d93bee1640ebcad15a694302d487'

GITHUB_URL = 'https://{0}@github.com/ekonstankiewicz/dw_matrix.git'.format(GITHUB_TOKEN)
GITHUB_URL
# Out:
# 'https://e47597a565b7d93bee1640ebcad15a694302d487@github.com/ekonstankiewicz/dw_matrix.git'

# %%
# !git clone {GITHUB_URL}
# Out:
# Cloning into 'dw_matrix'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 8 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (8/8), done.

# %%
cd dw_matrix/
# Out:
# [Errno 2] No such file or directory: 'dw_matrix/'
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
ls
# Out:
# LICENSE  README.md
